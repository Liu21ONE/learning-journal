# %%
a=[1,2,3]
b=a
b.append(4)
print(a)
# Out:
# [1, 2, 3, 4]

# %%
c="hello"
d=c
d=d+"world"
print(c)
print(d)
# Out:
# hello
# helloworld

# %%
import copy
a=[[1,2],[3,4]]
b=copy.copy(a)
b[0].append(999)
print(a)
print(b)
# Out:
# [[1, 2, 999], [3, 4]]
# [[1, 2, 999], [3, 4]]

# %%
import copy
a=[[1,2],[3,4]]
b=copy.deepcopy(a)
b[0].append(999)
print(a)
print(b)
# Out:
# [[1, 2], [3, 4]]
# [[1, 2, 999], [3, 4]]
